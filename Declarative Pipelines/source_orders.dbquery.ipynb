-- %%
create table  orders
(order_id int, 
 order_date  Date,
 customer_id int,
 order_status string );

 /*insert into orders values (1,'2022-01-01',1,'placed');
 insert into orders values (2,'2022-01-02',2,'cancelled');
 insert into orders values (3,'2022-01-03',3,'placed');
 insert into orders values (4,'2022-01-04',4,'completed');
 insert into orders values (5,'2022-01-05',5,'completed'); */                  

select *from orders;


 insert into orders values (6,'2022-01-06',6,'placed');
 insert into orders values (7,'2022-01-07',7,'completed');
